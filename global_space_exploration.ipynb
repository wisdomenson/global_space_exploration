# %% [markdown]
# importation & understanding of data

# %%
#space_exp = global space exploration
import pandas as pd

space_exp = pd.read_csv('Global_Space_Exploration_Dataset.csv')
space_exp
# Out:
#      Country  Year                                 Mission Name Mission Type  \
# 0      China  2008             Sharable tertiary superstructure       Manned
# 1      Japan  2018          Re-engineered composite flexibility       Manned
# 2     Israel  2013          Reactive disintermediate projection       Manned
# 3        UAE  2010     Grass-roots 6thgeneration implementation     Unmanned
# 4      India  2006              Balanced discrete orchestration       Manned
# ...      ...   ...                                          ...          ...
# 2995   China  2023                Synergistic scalable intranet       Manned
# 2996  France  2009           Team-oriented value-added extranet       Manned
# 2997   India  2020              Face-to-face even-keeled matrix     Unmanned
# 2998  Russia  2002               Open-source secondary software       Manned
# 2999   Japan  2014  Public-key cohesive artificial intelligence       Manned
#
# ...

# %%
#space_exp_ds = space exploration dataset
space_exp_ds = space_exp.copy()

# %%
space_exp_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  3000 non-null   object
#  1   Year                     3000 non-null   int64
#  2   Mission Name             3000 non-null   object
#  3   Mission Type             3000 non-null   object
#  4   Launch Site              3000 non-null   object
#  5   Satellite Type           3000 non-null   object
#  6   Budget (in Billion $)    3000 non-null   float64
#  7   Success Rate (%)         3000 non-null   int64
#  8   Technology Used          3000 non-null   object
#  9   Environmental Impact     3000 non-null   object
#  10  Collaborating Countries  3000 non-null   object
#  11  Duration (in Days)       3000 non-null   int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 281.4+ KB

# %%
space_exp_ds.describe()
# Out:
#               Year  Budget (in Billion $)  Success Rate (%)  \
# count  3000.000000            3000.000000       3000.000000
# mean   2012.471000              25.428917         74.985000
# std       7.437177              14.108438         14.945252
# min    2000.000000               0.530000         50.000000
# 25%    2006.000000              12.977500         62.000000
# 50%    2012.000000              25.495000         75.000000
# 75%    2019.000000              37.597500         88.000000
# max    2025.000000              49.970000        100.000000
#
#        Duration (in Days)
# count         3000.000000
# mean           181.483000
# std            104.983822
# min              1.000000
# 25%             91.000000
# 50%            180.000000
# 75%            272.000000
# max            365.000000

# %%
space_exp_ds.duplicated().value_counts()
# Out:
# False    3000
# Name: count, dtype: int64

# %%
space_exp_ds.columns
# Out:
# Index(['Country', 'Year', 'Mission Name', 'Mission Type', 'Launch Site',
#        'Satellite Type', 'Budget (in Billion $)', 'Success Rate (%)',
#        'Technology Used', 'Environmental Impact', 'Collaborating Countries',
#        'Duration (in Days)'],
#       dtype='object')

# %%
#checking & cleaning by columns
#Country column
space_exp_ds['Country']
# Out:
# 0        China
# 1        Japan
# 2       Israel
# 3          UAE
# 4        India
#          ...
# 2995     China
# 2996    France
# 2997     India
# 2998    Russia
# 2999     Japan
# Name: Country, Length: 3000, dtype: object

# %%
space_exp_ds.Country.describe()
# Out:
# count      3000
# unique       10
# top       China
# freq        322
# Name: Country, dtype: object

# %%
space_exp_ds.Country.unique()
# Out:
# array(['China', 'Japan', 'Israel', 'UAE', 'India', 'USA', 'Germany',
#        'France', 'UK', 'Russia'], dtype=object)

# %%
space_exp_ds.Country.isna().value_counts()
# Out:
# Country
# False    3000
# Name: count, dtype: int64

# %%
space_exp_ds.Country.sample(5)
# Out:
# 191      Japan
# 2292    France
# 1457     Japan
# 2683       USA
# 517      India
# Name: Country, dtype: object

# %%
#year column
space_exp_ds.Year
# Out:
# 0       2008
# 1       2018
# 2       2013
# 3       2010
# 4       2006
#         ...
# 2995    2023
# 2996    2009
# 2997    2020
# 2998    2002
# 2999    2014
# Name: Year, Length: 3000, dtype: int64

# %%
space_exp_ds['Year'].describe()
# Out:
# count    3000.000000
# mean     2012.471000
# std         7.437177
# min      2000.000000
# 25%      2006.000000
# 50%      2012.000000
# 75%      2019.000000
# max      2025.000000
# Name: Year, dtype: float64

# %%
space_exp_ds.Year.unique()
# Out:
# array([2008, 2018, 2013, 2010, 2006, 2011, 2012, 2024, 2014, 2007, 2023,
#        2002, 2020, 2017, 2019, 2003, 2015, 2022, 2004, 2025, 2009, 2016,
#        2000, 2005, 2001, 2021], dtype=int64)

# %%
space_exp_ds.Year.isna().value_counts()
# Out:
# Year
# False    3000
# Name: count, dtype: int64

# %%
#Mission Name column
space_exp_ds['Mission Name']
# Out:
# 0                  Sharable tertiary superstructure
# 1               Re-engineered composite flexibility
# 2               Reactive disintermediate projection
# 3          Grass-roots 6thgeneration implementation
# 4                   Balanced discrete orchestration
#                            ...
# 2995                  Synergistic scalable intranet
# 2996             Team-oriented value-added extranet
# 2997                Face-to-face even-keeled matrix
# 2998                 Open-source secondary software
# 2999    Public-key cohesive artificial intelligence
# Name: Mission Name, Length: 3000, dtype: object

# %%
space_exp_ds['Mission Name'].describe()
# Out:
# count                                     3000
# unique                                    2996
# top       Diverse non-volatile instruction set
# freq                                         2
# Name: Mission Name, dtype: object

# %%
space_exp_ds['Mission Name'].isna().value_counts()
# Out:
# Mission Name
# False    3000
# Name: count, dtype: int64

# %%
space_exp_ds['Mission Name'].sample(5)
# Out:
# 292           Re-engineered impactful implementation
# 516                   Advanced multimedia definition
# 798               User-centric secondary utilization
# 1056              Versatile encompassing contingency
# 2729    Triple-buffered demand-driven conglomeration
# Name: Mission Name, dtype: object

# %%
#Mission Type column
space_exp_ds['Mission Type']
# Out:
# 0         Manned
# 1         Manned
# 2         Manned
# 3       Unmanned
# 4         Manned
#           ...
# 2995      Manned
# 2996      Manned
# 2997    Unmanned
# 2998      Manned
# 2999      Manned
# Name: Mission Type, Length: 3000, dtype: object

# %%
space_exp_ds['Mission Type'].describe()
# Out:
# count       3000
# unique         2
# top       Manned
# freq        1528
# Name: Mission Type, dtype: object

# %%
space_exp_ds['Mission Type'].isna().value_counts()
# Out:
# Mission Type
# False    3000
# Name: count, dtype: int64

# %%
space_exp_ds['Mission Type'].sample(5)
# Out:
# 515     Unmanned
# 2629    Unmanned
# 1370    Unmanned
# 368     Unmanned
# 769       Manned
# Name: Mission Type, dtype: object

# %%
#Launch site column
space_exp_ds['Launch Site']
# Out:
# 0               Sheilatown
# 1             New Ericfurt
# 2         Port Kaitlynstad
# 3                Mariastad
# 4       North Jasonborough
#                ...
# 2995           East Shawna
# 2996        Douglasborough
# 2997             Bellhaven
# 2998            Deniseview
# 2999         Port Brittany
# Name: Launch Site, Length: 3000, dtype: object

# %%
space_exp_ds['Launch Site'].describe()
# Out:
# count             3000
# unique            2702
# top       West Michael
# freq                 5
# Name: Launch Site, dtype: object

# %%
space_exp_ds['Launch Site'].isna().value_counts()
# Out:
# Launch Site
# False    3000
# Name: count, dtype: int64

# %%
space_exp_ds['Launch Site'].sample(5)
# Out:
# 2912      East Bryan
# 162     East Lindsey
# 2724        Amymouth
# 429          Lambury
# 1428       Johnburgh
# Name: Launch Site, dtype: object

# %%
#satellite type column
space_exp_ds['Satellite Type']
# Out:
# 0       Communication
# 1       Communication
# 2       Communication
# 3                 Spy
# 4             Weather
#             ...
# 2995              Spy
# 2996    Communication
# 2997          Weather
# 2998          Weather
# 2999       Navigation
# Name: Satellite Type, Length: 3000, dtype: object

# %%
space_exp_ds['Satellite Type'].describe()
# Out:
# count         3000
# unique           5
# top       Research
# freq           649
# Name: Satellite Type, dtype: object

# %%
space_exp_ds['Satellite Type'].isna().value_counts()
# Out:
# Satellite Type
# False    3000
# Name: count, dtype: int64

# %%
space_exp_ds['Satellite Type'].unique()
# Out:
# array(['Communication', 'Spy', 'Weather', 'Research', 'Navigation'],
#       dtype=object)

# %%
space_exp_ds['Satellite Type'].sample(5)
# Out:
# 2644              Spy
# 2019       Navigation
# 1190         Research
# 1854    Communication
# 1061          Weather
# Name: Satellite Type, dtype: object

# %%
#budget column
space_exp_ds['Budget (in Billion $)']
# Out:
# 0       16.20
# 1       29.04
# 2       28.73
# 3       37.27
# 4       18.95
#         ...
# 2995    22.11
# 2996    47.72
# 2997    14.58
# 2998    13.69
# 2999    20.51
# Name: Budget (in Billion $), Length: 3000, dtype: float64

# %%
space_exp_ds['Budget (in Billion $)'].describe()
# Out:
# count    3000.000000
# mean       25.428917
# std        14.108438
# min         0.530000
# 25%        12.977500
# 50%        25.495000
# 75%        37.597500
# max        49.970000
# Name: Budget (in Billion $), dtype: float64

# %%
space_exp_ds['Budget (in Billion $)'].isna().value_counts()
# Out:
# Budget (in Billion $)
# False    3000
# Name: count, dtype: int64

# %%
space_exp_ds['Budget (in Billion $)'].sample(5)
# Out:
# 764     42.42
# 497      9.67
# 520     35.19
# 2910     0.67
# 186     15.34
# Name: Budget (in Billion $), dtype: float64

# %%
#success rate column
space_exp_ds['Success Rate (%)']
# Out:
# 0       90
# 1       99
# 2       54
# 3       58
# 4       91
#         ..
# 2995    68
# 2996    96
# 2997    83
# 2998    66
# 2999    95
# Name: Success Rate (%), Length: 3000, dtype: int64

# %%
space_exp_ds['Success Rate (%)'].describe()
# Out:
# count    3000.000000
# mean       74.985000
# std        14.945252
# min        50.000000
# 25%        62.000000
# 50%        75.000000
# 75%        88.000000
# max       100.000000
# Name: Success Rate (%), dtype: float64

# %%
space_exp_ds['Success Rate (%)'].unique()
# Out:
# array([ 90,  99,  54,  58,  91,  85,  81,  69,  60,  66,  92,  53,  65,
#         73,  61,  71,  75,  50,  95,  57,  68,  56,  87,  62,  88,  82,
#         64,  97,  72,  93,  98,  63,  76,  55,  67,  74,  79,  78,  59,
#         52,  77, 100,  86,  89,  96,  94,  83,  80,  70,  51,  84],
#       dtype=int64)

# %%
space_exp_ds['Success Rate (%)'].isna().value_counts()
# Out:
# Success Rate (%)
# False    3000
# Name: count, dtype: int64

# %%
space_exp_ds['Success Rate (%)'].sample(5)
# Out:
# 1389    52
# 1065    51
# 1122    97
# 755     55
# 2259    84
# Name: Success Rate (%), dtype: int64

# %%
#tech used column
space_exp_ds['Technology Used']
# Out:
# 0       Nuclear Propulsion
# 1         Solar Propulsion
# 2            AI Navigation
# 3       Traditional Rocket
# 4         Solar Propulsion
#                ...
# 2995    Traditional Rocket
# 2996    Nuclear Propulsion
# 2997       Reusable Rocket
# 2998      Solar Propulsion
# 2999    Nuclear Propulsion
# Name: Technology Used, Length: 3000, dtype: object

# %%
space_exp_ds['Technology Used'].describe()
# Out:
# count                   3000
# unique                     5
# top       Traditional Rocket
# freq                     650
# Name: Technology Used, dtype: object

# %%
space_exp_ds['Technology Used'].unique()
# Out:
# array(['Nuclear Propulsion', 'Solar Propulsion', 'AI Navigation',
#        'Traditional Rocket', 'Reusable Rocket'], dtype=object)

# %%
#environmental impact column
space_exp_ds['Environmental Impact']
# Out:
# 0       Medium
# 1         High
# 2       Medium
# 3          Low
# 4       Medium
#          ...
# 2995    Medium
# 2996    Medium
# 2997       Low
# 2998       Low
# 2999    Medium
# Name: Environmental Impact, Length: 3000, dtype: object

# %%
space_exp_ds['Environmental Impact'].describe()
# Out:
# count       3000
# unique         3
# top       Medium
# freq        1032
# Name: Environmental Impact, dtype: object

# %%
space_exp_ds['Environmental Impact'].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
#collaborating countries column
space_exp_ds['Collaborating Countries']
# Out:
# 0          France, UK, Russia
# 1             Germany, Israel
# 2          China, Israel, USA
# 3                         USA
# 4        Israel, China, India
#                 ...
# 2995                   Israel
# 2996      Germany, Israel, UK
# 2997    Japan, Russia, France
# 2998       UAE, India, France
# 2999                   Israel
# Name: Collaborating Countries, Length: 3000, dtype: object

# %%
space_exp_ds['Collaborating Countries'].describe()
# Out:
# count        3000
# unique        639
# top       Germany
# freq          115
# Name: Collaborating Countries, dtype: object

# %%
space_exp_ds['Collaborating Countries'].sample(5)
# Out:
# 1603      China, Russia, UAE
# 2574            China, Japan
# 2668          Germany, China
# 30      Russia, Germany, USA
# 2560                     UAE
# Name: Collaborating Countries, dtype: object

# %%
#duration column
space_exp_ds['Duration (in Days)']
# Out:
# 0       112
# 1       236
# 2       238
# 3       186
# 4       277
#        ...
# 2995    338
# 2996    336
# 2997      3
# 2998    339
# 2999    210
# Name: Duration (in Days), Length: 3000, dtype: int64

# %%
space_exp_ds['Duration (in Days)'].describe()
# Out:
# count    3000.000000
# mean      181.483000
# std       104.983822
# min         1.000000
# 25%        91.000000
# 50%       180.000000
# 75%       272.000000
# max       365.000000
# Name: Duration (in Days), dtype: float64

# %%
space_exp_ds['Duration (in Days)'].sample(5)
# Out:
# 2860     13
# 2629    202
# 2336    211
# 2439    170
# 2825     80
# Name: Duration (in Days), dtype: int64

# %% [markdown]
# Analysis & Visualisation

# %%
space_exp_ds.sample(2)
# Out:
#      Country  Year                                       Mission Name  \
# 2224      UK  2010  Open-architected solution-oriented artificial ...
# 2993  Israel  2004                            Monitored static access
#
#      Mission Type        Launch Site Satellite Type  Budget (in Billion $)  \
# 2224     Unmanned  South Michaeltown       Research                  13.79
# 2993       Manned        Paceborough        Weather                  40.25
#
#       Success Rate (%)     Technology Used Environmental Impact  \
# 2224                72  Traditional Rocket                 High
# 2993                84       AI Navigation                  Low
#
#      Collaborating Countries  Duration (in Days)
# 2224    Russia, India, China                  46
# 2993     Germany, Japan, UAE                 305

# %%
#top 10 countries with space exploration missions
space_exp_ds['Country'].value_counts().sort_values()
# Out:
# Country
# Germany    250
# Russia     289
# Japan      290
# India      294
# USA        304
# UAE        305
# France     311
# Israel     313
# China      322
# UK         322
# Name: count, dtype: int64

# %%
#top 10 countries with space exploration missions
import matplotlib.pyplot as plt 
import seaborn as sbn 

#plt.plot(space_exp_ds['Country'].value_counts().sort_values())

sbn.set_style('darkgrid')
plt.figure(figsize=(6,4))
space_exp_ds['Country'].value_counts().sort_values().plot(kind='barh', color='g')
plt.xlabel('Frequency')
plt.title('Top 10 Countries With Most Space Exploration Missions (2000 - 2025)')
plt.xlim(0,350)
# Out:
# (0.0, 350.0)

# %%
#Average Mission Budget and Success Rate by Country
space_exp_ds[['Country','Success Rate (%)','Budget (in Billion $)']]
# Out:
#      Country  Success Rate (%)  Budget (in Billion $)
# 0      China                90                  16.20
# 1      Japan                99                  29.04
# 2     Israel                54                  28.73
# 3        UAE                58                  37.27
# 4      India                91                  18.95
# ...      ...               ...                    ...
# 2995   China                68                  22.11
# 2996  France                96                  47.72
# 2997   India                83                  14.58
# 2998  Russia                66                  13.69
# 2999   Japan                95                  20.51
#
# [3000 rows x 3 columns]

# %%
#Average Mission Budget and Success Rate by Country
space_exp_ds[['Country','Success Rate (%)',
              'Budget (in Billion $)']].groupby('Country').mean().sort_values(by='Budget (in Billion $)')
# Out:
#          Success Rate (%)  Budget (in Billion $)
# Country
# Germany         76.248000              24.127200
# UAE             74.734426              24.577377
# UK              75.043478              24.930839
# Japan           74.451724              25.174862
# Israel          74.108626              25.445942
# China           74.990683              25.657112
# Russia          75.252595              25.687439
# France          75.463023              25.750579
# USA             74.042763              26.054178
# India           75.765306              26.706361

# %%
#Average Mission Budget and Success Rate by Country
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('dark')
#Group and prepare the data
avg_data = space_exp_ds[['Country', 'Success Rate (%)', 
                         'Budget (in Billion $)']].groupby('Country').mean().sort_values(by='Budget (in Billion $)')

#Create the plot
fig, ax1 = plt.subplots(figsize=(7, 4))
plt.xlabel('Country')

#Barchart for Budget
ax1.bar(avg_data.index, avg_data['Budget (in Billion $)'], color='skyblue', label='Avg Budget (Billion $)')
ax1.set_ylabel('Average Budget (in Billion $)', color='teal')
ax1.tick_params(axis='y', labelcolor='teal')
ax1.set_xticklabels(avg_data.index, rotation=30, ha='right')


#Create a second y-axis for Success Rate
ax2 = ax1.twinx()
ax2.plot(avg_data.index, avg_data['Success Rate (%)'], color='green', marker='o', label='Avg Success Rate (%)')
ax2.set_ylabel('Average Success Rate (%)', color='green')
ax2.tick_params(axis='y', labelcolor='green')

#Titles and layout
plt.title('Average Mission Budget and Success Rate by Country')
fig.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xlabel('Country')
plt.show()
# Out:
# C:\Users\kofi\AppData\Local\Temp\ipykernel_13600\3631585299.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(avg_data.index, rotation=30, ha='right')

# %%
#Proportion of environmental impact of space exploration
space_exp_ds['Environmental Impact'].value_counts().sort_index()
# Out:
# Environmental Impact
# High       958
# Low       1010
# Medium    1032
# Name: count, dtype: int64

# %%
#Proportion of environmental impact of space exploration
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('dark')
plt.figure(figsize=(7,4))
space_exp_ds['Environmental Impact'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.legend(loc='upper left')
plt.ylabel('')
plt.title('Space Exploration Impact On The Environment')
# Out:
# Text(0.5, 1.0, 'Space Exploration Impact On The Environment')

# %%
#country's mission impact on environment
space_exp_ds[['Country','Environmental Impact']]
# Out:
#      Country Environmental Impact
# 0      China               Medium
# 1      Japan                 High
# 2     Israel               Medium
# 3        UAE                  Low
# 4      India               Medium
# ...      ...                  ...
# 2995   China               Medium
# 2996  France               Medium
# 2997   India                  Low
# 2998  Russia                  Low
# 2999   Japan               Medium
#
# [3000 rows x 2 columns]

# %%
#country's mission impact on environment
space_exp_ds[['Country','Environmental Impact']].groupby('Country').value_counts().sort_index()
# Out:
# Country  Environmental Impact
# China    High                    112
#          Low                     110
#          Medium                  100
# France   High                    101
#          Low                     103
#          Medium                  107
# Germany  High                     83
#          Low                      85
#          Medium                   82
# India    High                     90
#          Low                      93
#          Medium                  111
# Israel   High                    109
#          Low                     105
#          Medium                   99
# Japan    High                     94
#          Low                      95
#          Medium                  101
# Russia   High                     88
#          Low                      91
#          Medium                  110
# UAE      High                     84
#          Low                     115
#          Medium                  106
# ...

# %%
#country's mission impact on environment
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('darkgrid')
# Group and count environmental impact per country
impact_counts = space_exp_ds.groupby(['Country', 'Environmental Impact']).size().unstack(fill_value=0)

# Sort countries by total missions in ascending order
impact_counts = impact_counts.loc[impact_counts.sum(axis=1).sort_values().index]

# Plot stacked bar chart
impact_counts.plot(kind='bar', stacked=False, figsize=(7, 4))
plt.title("Country's Missions Impact On The Environment")
plt.xlabel('Country')
plt.ylabel('Impact Level')
plt.legend(title='Environmental Impact', bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.legend(title='Environmental Impact', loc='lower right')
plt.xticks(rotation=30)
plt.ylim(top=350)
plt.tight_layout() 
plt.show()
'''
# Out:
# '\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sbn\n\nsbn.set_style(\'darkgrid\')\n# Group and count environmental impact per country\nimpact_counts = space_exp_ds.groupby([\'Country\', \'Environmental Impact\']).size().unstack(fill_value=0)\n\n# Sort countries by total missions in ascending order\nimpact_counts = impact_counts.loc[impact_counts.sum(axis=1).sort_values().index]\n\n# Plot stacked bar chart\nimpact_counts.plot(kind=\'bar\', stacked=False, figsize=(7, 4))\nplt.title("Country\'s Missions Impact On The Environment")\nplt.xlabel(\'Country\')\nplt.ylabel(\'Impact Level\')\nplt.legend(title=\'Environmental Impact\', bbox_to_anchor=(1.05, 1), loc=\'upper left\')\n#plt.legend(title=\'Environmental Impact\', loc=\'lower right\')\nplt.xticks(rotation=30)\nplt.ylim(top=350)\nplt.tight_layout() \nplt.show()\n'

# %%
#Country's Missions Impact On The Environment
import pandas as pd
import seaborn as sbn

import matplotlib.pyplot as plt

sbn.set_style('darkgrid')
# Group and count environmental impact per country
impact_counts = space_exp_ds.groupby(['Country', 'Environmental Impact']).size().unstack(fill_value=0)

# Sort countries by total missions in ascending order
impact_counts = impact_counts.loc[impact_counts.sum(axis=1).sort_values().index]

# Plot stacked bar chart
ax = impact_counts.plot(kind='bar', stacked=True, figsize=(7, 4))
plt.title("Country's Missions Impact On The Environment")
plt.xlabel('Country')
plt.ylabel('Impact Level')
plt.legend(title='Environmental Impact', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=20)
plt.ylim(top=350)
plt.tight_layout()

# Add figures to the bars
for c_idx, country in enumerate(impact_counts.index):
    cumulative = 0
    for i, impact in enumerate(impact_counts.columns):
        value = impact_counts.loc[country, impact]
        if value > 0:
            ax.text(
                c_idx, 
                cumulative + value / 2, 
                str(value), 
                ha='center', 
                va='center', 
                fontsize=8,
                color='black' 
                #color='white' if i != 0 else 'black'
            )
            cumulative += value

plt.show()

# %%
#Global Space Exploration Missions By Year (2000 - 2025)
space_exp_ds['Year'].value_counts().sort_index()
# Out:
# Year
# 2000    114
# 2001    121
# 2002    126
# 2003    106
# 2004    106
# 2005    105
# 2006    116
# 2007     99
# 2008    115
# 2009    129
# 2010    109
# 2011    142
# 2012    125
# 2013    127
# 2014    118
# 2015    103
# 2016    109
# 2017    118
# 2018    119
# 2019    110
# 2020    116
# 2021    116
# 2022    124
# 2023    108
# 2024    122
# 2025     97
# Name: count, dtype: int64

# %%
#Global Space Exploration Missions By Year (2000 - 2025)
import matplotlib.pyplot as plt 
import seaborn as sbn 

sbn.set_style('darkgrid')
plt.figure(figsize=(6,4))
space_exp_ds['Year'].value_counts().sort_index().plot(color='g',marker='o')
plt.ylim(top=150)
plt.title('Global Space Exploration Missions By Year (2000 - 2025)')
plt.ylabel('Frequency')
plt.tight_layout()

# %%
#mission type proportion of space exploration (2000-2025)
space_exp_ds['Mission Type'].value_counts()
# Out:
# Mission Type
# Manned      1528
# Unmanned    1472
# Name: count, dtype: int64

# %%
#mission type proportion of space exploration (2000-2025)
import matplotlib.pyplot as plt
import seaborn as sbn

#sbn.set_style('darkgrid')
plt.figure(figsize=(6,4))
space_exp_ds['Mission Type'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.legend(title='Mission Type', loc='lower left')
plt.title('Common Mission Type of Global Space Exploration (2000-2025)')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
#Mission Frequency Over Time by Mission Type
space_exp_ds[['Mission Type','Year']]
# Out:
#      Mission Type  Year
# 0          Manned  2008
# 1          Manned  2018
# 2          Manned  2013
# 3        Unmanned  2010
# 4          Manned  2006
# ...           ...   ...
# 2995       Manned  2023
# 2996       Manned  2009
# 2997     Unmanned  2020
# 2998       Manned  2002
# 2999       Manned  2014
#
# [3000 rows x 2 columns]

# %%
#Mission Frequency Over Time by Mission Type
space_exp_ds[['Mission Type','Year']].groupby('Mission Type').value_counts()
# Out:
# Mission Type  Year
# Manned        2011    76
#               2002    74
#               2009    71
#               2013    71
#               2012    70
#               2020    64
#               2022    61
#               2014    60
#               2018    60
#               2017    59
#               2016    58
#               2023    58
#               2025    58
#               2007    57
#               2006    55
#               2008    55
#               2019    55
#               2000    54
#               2004    54
#               2015    54
#               2010    53
#               2001    51
#               2003    51
#               2021    51
#               2024    50
#               2005    48
# Unmanned      2024    72
#               2001    70
#               2011    66
#               2021    65
#               2022    63
#               2006    61
#               2000    60
#               2008    60
#               2017    59
#               2018    59
# ...

# %%
#Mission Frequency Over Time by Mission Type
import matplotlib.pyplot as plt

# Group by 'Mission Type' and 'Year', and count the occurrences
mission_type_year_counts = space_exp_ds.groupby(['Mission Type', 'Year']).size().unstack(fill_value=0)

# Plot the data
mission_type_year_counts.T.plot(figsize=(6, 4), marker='o')
plt.title('Mission Frequency Over Time by Mission Type')
plt.xlabel('Year')
plt.ylabel('Number of Missions')
plt.legend(title='Mission Type', loc='lower center')
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
#average space missions duration over the years
space_exp_ds[['Year','Duration (in Days)']].groupby('Year').mean().sort_values(by='Duration (in Days)')
# Out:
#       Duration (in Days)
# Year
# 2003          162.886792
# 2019          163.245455
# 2001          170.388430
# 2025          170.618557
# 2005          171.704762
# 2018          173.890756
# 2008          174.600000
# 2021          174.689655
# 2006          177.094828
# 2010          177.513761
# 2011          177.852113
# 2022          178.838710
# 2020          180.336207
# 2000          181.394737
# 2012          181.864000
# 2015          181.873786
# 2009          184.224806
# 2007          186.373737
# 2014          186.796610
# 2017          191.237288
# 2016          191.779817
# 2023          192.305556
# 2024          194.795082
# 2002          194.801587
# 2004          196.047170
# 2013          197.000000

# %%
#average space missions duration over the years
import matplotlib.pyplot as plt 
import seaborn as sbn

#plt.figure(figsize=(5,4))
sbn.set_style('darkgrid')
# Grouping by 'Year' and calculating the mean of 'Duration (in Days)', then sorting
avg_duration_per_year = space_exp_ds[['Year', 'Duration (in Days)']].groupby('Year').mean().sort_values(by='Duration (in Days)')

# Plotting the data
avg_duration_per_year.plot(kind='bar', figsize=(7, 5),legend=False)
plt.title('Average Missions Duration Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Duration (in Days)')
plt.xticks(rotation=45)
#plt.tight_layout()
plt.show()

# %%
#correlation
space_exp_ds[['Budget (in Billion $)','Duration (in Days)','Success Rate (%)']]
# Out:
#       Budget (in Billion $)  Duration (in Days)  Success Rate (%)
# 0                     16.20                 112                90
# 1                     29.04                 236                99
# 2                     28.73                 238                54
# 3                     37.27                 186                58
# 4                     18.95                 277                91
# ...                     ...                 ...               ...
# 2995                  22.11                 338                68
# 2996                  47.72                 336                96
# 2997                  14.58                   3                83
# 2998                  13.69                 339                66
# 2999                  20.51                 210                95
#
# [3000 rows x 3 columns]

# %%
#correlation btn budget, duration and success rate of space missions
column_correlation = space_exp_ds[['Budget (in Billion $)','Duration (in Days)','Success Rate (%)']]

# Calculate the correlation matrix
cor_matrix = column_correlation.corr()
cor_matrix
# Out:
#                        Budget (in Billion $)  Duration (in Days)  \
# Budget (in Billion $)               1.000000            0.013908
# Duration (in Days)                  0.013908            1.000000
# Success Rate (%)                   -0.001052           -0.010015
#
#                        Success Rate (%)
# Budget (in Billion $)         -0.001052
# Duration (in Days)            -0.010015
# Success Rate (%)               1.000000

# %%
#correlation
import matplotlib.pyplot as plt
import seaborn as sbn

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
#sbn.heatmap(cor_matrix, annot=True, cmap='coolwarm','crest','cool', fmt=".2f")
sbn.heatmap(cor_matrix, annot=True, cmap='crest', fmt=".2f")

plt.title('Correlation Betweeen Mission Budget, Duration and Success Rate')
plt.xticks(rotation = 10)
#plt.tight_layout()
plt.show()

# %%
space_exp_ds['Launch Site']
# Out:
# 0               Sheilatown
# 1             New Ericfurt
# 2         Port Kaitlynstad
# 3                Mariastad
# 4       North Jasonborough
#                ...
# 2995           East Shawna
# 2996        Douglasborough
# 2997             Bellhaven
# 2998            Deniseview
# 2999         Port Brittany
# Name: Launch Site, Length: 3000, dtype: object

# %%
#top 10 launch sites
space_exp_ds['Launch Site'].value_counts().sort_values().tail(10)
# Out:
# Launch Site
# New Michael      4
# Port Jennifer    4
# South Matthew    4
# West Brian       4
# Michaelview      4
# Port Michael     4
# Port Emily       4
# Ashleymouth      4
# New James        4
# West Michael     5
# Name: count, dtype: int64

# %%
#top 20 launch sites

import matplotlib.pyplot as plt
import seaborn as sbn 

sbn.set_style('darkgrid')
space_exp_ds['Launch Site'].value_counts().sort_values().tail(20).plot(kind='barh',color='r')
plt.title('Top 20 Lauched Sites Of Global Space Exploration (2000-2025)')
plt.xlabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %%
#Common Satellite Type Launched To Space
space_exp_ds['Satellite Type'].value_counts()
# Out:
# Satellite Type
# Research         649
# Weather          617
# Communication    588
# Spy              585
# Navigation       561
# Name: count, dtype: int64

# %%
#Common Satellite Type Launched To Space
import matplotlib.pyplot as plt
import seaborn as sbn

#plt.figure(figsize=(5,4))
space_exp_ds['Satellite Type'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.ylabel('')
#plt.legend(title='',loc='upper right')
plt.legend(title='Satellite Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Common Satellite Type Launched To Space (2000-2025)')
# Out:
# Text(0.5, 1.0, 'Common Satellite Type Launched To Space (2000-2025)')

# %%
#total budget used in space exploration from 2000 - 2025
total_budget = space_exp_ds['Budget (in Billion $)'].sum()
print('The total budget used in space exploration from 2000 - 2025 is', total_budget)
# Out:
# The total budget used in space exploration from 2000 - 2025 is 76286.75

# %%
#total budget used in space exploration from 2000 - 2025
import matplotlib.pyplot as plt

# Plotting the total budget as a single value (bar)
total_budget = space_exp_ds['Budget (in Billion $)'].sum()
plt.bar(['Total Budget'], [total_budget], color='teal')
plt.ylabel('Budget (in Billion $)')
plt.title('Total Budget Used in Space Exploration (2000 - 2025)')
plt.show()

# %%
#budget on various satellite type launched
space_exp_ds[['Satellite Type','Budget (in Billion $)']]
# Out:
#      Satellite Type  Budget (in Billion $)
# 0     Communication                  16.20
# 1     Communication                  29.04
# 2     Communication                  28.73
# 3               Spy                  37.27
# 4           Weather                  18.95
# ...             ...                    ...
# 2995            Spy                  22.11
# 2996  Communication                  47.72
# 2997        Weather                  14.58
# 2998        Weather                  13.69
# 2999     Navigation                  20.51
#
# [3000 rows x 2 columns]

# %%
#budget on various satellite type launched
satt_type_budget = space_exp_ds[['Satellite Type',
              'Budget (in Billion $)']].groupby('Satellite Type').sum().sort_values(by='Budget (in Billion $)')
satt_type_budget
# Out:
#                 Budget (in Billion $)
# Satellite Type
# Communication                14408.39
# Navigation                   14462.07
# Spy                          14689.00
# Weather                      15553.10
# Research                     17174.19

# %%
#budget on various satellite type launched
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('whitegrid')
plt.figure(figsize=(5,4))
satt_type_budget.plot(kind='area', legend=False, color='teal')
#plt.plot(satt_type_budget)
plt.title('Total Budget On Various Satellite Type Launched To Space')
plt.ylabel('Budget (in Billion $)')
plt.xlabel('Satellite Type')
plt.ylim(top=20000)
plt.xticks(rotation=10)
#plt.tight_layout()
plt.show()

# %%
#Satellite Type launched To Space by Various Countries
space_exp_ds[['Satellite Type','Country']]
# Out:
#      Satellite Type Country
# 0     Communication   China
# 1     Communication   Japan
# 2     Communication  Israel
# 3               Spy     UAE
# 4           Weather   India
# ...             ...     ...
# 2995            Spy   China
# 2996  Communication  France
# 2997        Weather   India
# 2998        Weather  Russia
# 2999     Navigation   Japan
#
# [3000 rows x 2 columns]

# %%
#Satellite Type Launched to space by Various Countries
space_exp_ds[['Satellite Type','Country']].groupby('Satellite Type').value_counts()
# Out:
# Satellite Type  Country
# Communication   China      74
#                 Japan      66
#                 UAE        66
#                 UK         65
#                 Russia     59
#                 USA        58
#                 Israel     57
#                 India      53
#                 France     46
#                 Germany    44
# Navigation      Israel     68
#                 China      63
#                 USA        61
#                 France     59
#                 Germany    58
#                 UAE        56
#                 India      55
#                 Japan      49
#                 Russia     47
#                 UK         45
# Research        Russia     82
#                 USA        77
#                 UK         70
#                 India      68
#                 China      63
#                 Israel     61
#                 Japan      61
#                 France     60
#                 UAE        58
#                 Germany    49
# ...

# %%
#Satellite Type Launched to space by Various Countries
import matplotlib.pyplot as plt
import seaborn as sbn 

sbn.set_style('whitegrid')
# Get the counts of each (Satellite Type, Country) pair
sat_country_counts = space_exp_ds[['Satellite Type', 'Country']].groupby('Satellite Type').value_counts()

# Convert to DataFrame for plotting
sat_country_counts = sat_country_counts.unstack(fill_value=0)

# Plot as a stacked/unstacked bar chart
sat_country_counts.T.plot(kind='bar', stacked=False, figsize=(7, 4))
plt.title('Satellite Type Launched To Space by Various Countries')
plt.xlabel('Country')
plt.ylabel('Number of Missions')
plt.legend(title='Satellite Type', bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.legend(title='Satellite Type', loc='lower right')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
#Common Technology Used In Space Exploration (2000-2025)
space_exp_ds['Technology Used'].value_counts()
# Out:
# Technology Used
# Traditional Rocket    650
# AI Navigation         609
# Solar Propulsion      598
# Reusable Rocket       581
# Nuclear Propulsion    562
# Name: count, dtype: int64

# %%
#Common Technology Used In Space Exploration (2000-2025)
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('dark')
space_exp_ds['Technology Used'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.ylabel('')
plt.title('Common Technology Used In Space Exploration (2000-2025)')
plt.legend(title='Technology Used', bbox_to_anchor=(1.05, 1), loc='upper left')
#plt.legend(loc='upper right')
plt.show()

# %%
#total budget on various tech used
space_exp_ds[['Technology Used','Budget (in Billion $)']]
# Out:
#          Technology Used  Budget (in Billion $)
# 0     Nuclear Propulsion                  16.20
# 1       Solar Propulsion                  29.04
# 2          AI Navigation                  28.73
# 3     Traditional Rocket                  37.27
# 4       Solar Propulsion                  18.95
# ...                  ...                    ...
# 2995  Traditional Rocket                  22.11
# 2996  Nuclear Propulsion                  47.72
# 2997     Reusable Rocket                  14.58
# 2998    Solar Propulsion                  13.69
# 2999  Nuclear Propulsion                  20.51
#
# [3000 rows x 2 columns]

# %%
#total budget on various tech used
tech_used_budget = space_exp_ds[['Technology Used',
              'Budget (in Billion $)']].groupby('Technology Used').sum().sort_values(by='Budget (in Billion $)')
tech_used_budget
# Out:
#                     Budget (in Billion $)
# Technology Used
# Nuclear Propulsion               13727.59
# Reusable Rocket                  14795.32
# Solar Propulsion                 15191.97
# AI Navigation                    15948.88
# Traditional Rocket               16622.99

# %%
#total budget on various tech used
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('whitegrid')
plt.figure(figsize=(5,4))
tech_used_budget.plot(kind='area', legend=False, color='skyblue')
plt.title('Total Budget On Various Technology Used For Space Missions')
plt.ylabel('Budget (in Billion $)')
plt.xlabel('Technology Used')
plt.ylim(top=18000)
plt.xticks(rotation=10)
#plt.tight_layout()
plt.show()

# %% [markdown]
# Explore Further Manned Mission & Others

# %%
#manned mission to space
#manned_mission = space_exp_ds[space_exp_ds['Mission Type'].str.contains('Manned')]
#manned_mission.head(2)

# %%
#Top 10 countries with manned mission to space
#manned_mission['Country'].value_counts().sort_values()

# %%
#Top 10 countries with manned mission to space
'''
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('darkgrid')
manned_mission['Country'].value_counts().sort_values().plot(kind='barh',color='b')
plt.title('Top 10 Countries With Manned Mission To Space')
plt.xlabel('Frequency')
plt.xlim(right=180)
'''
# Out:
# "\nimport matplotlib.pyplot as plt\nimport seaborn as sbn\n\nsbn.set_style('darkgrid')\nmanned_mission['Country'].value_counts().sort_values().plot(kind='barh',color='b')\nplt.title('Top 10 Countries With Manned Mission To Space')\nplt.xlabel('Frequency')\nplt.xlim(right=180)\n"

# %%
#manned mission by year
#manned_mission['Year'].value_counts().sort_values()

# %%
#manned mission by year
#manned_mission['Year'].value_counts().sort_values().plot(kind='bar')

# %%
#space_exp_ds[['Country','Year']]
#space_exp_ds[['Country','Year']].groupby('Country').value_counts()

'''
import matplotlib.pyplot as plt

# Step 1: Group by 'Country' and 'Year' and count the number of missions
country_year_counts = space_exp_ds.groupby(['Country', 'Year']).size().reset_index(name='Mission Count')

# Step 2: Pivot the data so each country becomes a separate line in the plot
pivot_df = country_year_counts.pivot(index='Year', columns='Country', values='Mission Count')

# Step 3: Plot the trends
pivot_df.plot(figsize=(12, 6), marker='o')
plt.title('Mission Frequency Over Time by Country')
plt.xlabel('Year')
plt.ylabel('Number of Missions')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(True)
plt.show()
'''
# Out:
# "\nimport matplotlib.pyplot as plt\n\n# Step 1: Group by 'Country' and 'Year' and count the number of missions\ncountry_year_counts = space_exp_ds.groupby(['Country', 'Year']).size().reset_index(name='Mission Count')\n\n# Step 2: Pivot the data so each country becomes a separate line in the plot\npivot_df = country_year_counts.pivot(index='Year', columns='Country', values='Mission Count')\n\n# Step 3: Plot the trends\npivot_df.plot(figsize=(12, 6), marker='o')\nplt.title('Mission Frequency Over Time by Country')\nplt.xlabel('Year')\nplt.ylabel('Number of Missions')\nplt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')\nplt.tight_layout()\nplt.grid(True)\nplt.show()\n"
